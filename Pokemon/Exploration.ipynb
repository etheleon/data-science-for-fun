# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline
sns.set(style="white", color_codes=True)

# %%
dataset = pd.read_csv("data/Pokemon.csv")

# %%
dataset.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation Legendary
# 0       65       65     45           1     False
# 1       80       80     60           1     False
# 2      100      100     80           1     False
# 3      122      120     80           1     False
# 4       60       50     65           1     False

# %%
# fig, axs = plt.subplots(ncols=3)
# sns.countplot(x="Generation", data=dataset, palette="Set3", ax=axs[0]);
sns.countplot(y="Type 1", data=dataset);

# %%
from bokeh.plotting import figure, output_notebook, show

# prepare some data
x = [1, 2, 3, 4, 5]
y = [6, 7, 2, 4, 5]

output_notebook()

# create a new plot with a title and axis labels
p = figure(title="simple line example", x_axis_label='x', y_axis_label='y')

# add a line renderer with legend and line thickness
p.line(x, y, legend="Temp.", line_width=2)

# show the results
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="49f29c8c-ca87-4627-9f29-055ebe7bb68f">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="62223fe8-0f5f-4c3a-99ca-de545d2e7d24"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("62223fe8-0f5f-4c3a-99ca-de545d2e7d24").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("62223fe8-0f5f-4c3a-99ca-de545d2e7d24");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '62223fe8-0f5f-4c3a-99ca-de545d2e7d24' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"925d9d65-4932-402b-80b1-267d07dca0f8":{"roots":{"references":[{"attributes":{},"id":"834828a4-bf89-474a-91c3-2dd95c53e574","type":"BasicTicker"},{"attributes":{"plot":{"id":"980fa5fe-2358-4812-aee1-07958389ee94","subtype":"Figure","type":"Plot"}},"id":"a1667e45-923d-46cf-9d67-22e1d03cd6db","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[1,2,3,4,5],"y":[6,7,2,4,5]}},"id":"f8243945-bcd7-4ee6-bee3-f26306a5ed67","type":"ColumnDataSource"},{"attributes":{"axis_label":"y","formatter":{"id":"b7a2d652-aeac-414c-b6a6-b03b3fa588d8","type":"BasicTickFormatter"},"plot":{"id":"980fa5fe-2358-4812-aee1-07958389ee94","subtype":"Figure","type":"Plot"},"ticker":{"id":"cdd7ab8d-c7c9-415a-ac03-cd532bc2b1d1","type":"BasicTicker"}},"id":"d1979ad9-2e45-478c-84f4-1d1b1eac866f","type":"LinearAxis"},{"attributes":{"plot":{"id":"980fa5fe-2358-4812-aee1-07958389ee94","subtype":"Figure","type":"Plot"}},"id":"4fb417e3-e67b-4573-b1ca-3b1f0a75f401","type":"PanTool"},{"attributes":{"overlay":{"id":"b95e11bc-b970-474b-9d9d-92fe3ca3996f","type":"BoxAnnotation"},"plot":{"id":"980fa5fe-2358-4812-aee1-07958389ee94","subtype":"Figure","type":"Plot"}},"id":"7fdc56a7-849c-4f84-8672-afc1c92fcf40","type":"BoxZoomTool"},{"attributes":{"callback":null},"id":"231d3de5-cd80-4713-b18a-7a13dcb6458b","type":"DataRange1d"},{"attributes":{"plot":{"id":"980fa5fe-2358-4812-aee1-07958389ee94","subtype":"Figure","type":"Plot"}},"id":"100febae-ec5b-4d59-a563-e2a143e8f893","type":"HelpTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"0e32b13b-dd19-4ab4-888f-c6041a879aee","type":"Line"},{"attributes":{"plot":{"id":"980fa5fe-2358-4812-aee1-07958389ee94","subtype":"Figure","type":"Plot"}},"id":"031b003e-62d7-4c77-8ece-6639852ac0b9","type":"ResetTool"},{"attributes":{"plot":{"id":"980fa5fe-2358-4812-aee1-07958389ee94","subtype":"Figure","type":"Plot"},"ticker":{"id":"834828a4-bf89-474a-91c3-2dd95c53e574","type":"BasicTicker"}},"id":"56229b17-d838-4f74-919e-a58acb6bbc5a","type":"Grid"},{"attributes":{"label":{"value":"Temp."},"renderers":[{"id":"249437d2-6b15-46a6-9b05-7f751c776ad7","type":"GlyphRenderer"}]},"id":"5de35316-6cc3-4eaa-b3ba-7e309de3bfd4","type":"LegendItem"},{"attributes":{},"id":"cdd7ab8d-c7c9-415a-ac03-cd532bc2b1d1","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"4fb417e3-e67b-4573-b1ca-3b1f0a75f401","type":"PanTool"},{"id":"a1667e45-923d-46cf-9d67-22e1d03cd6db","type":"WheelZoomTool"},{"id":"7fdc56a7-849c-4f84-8672-afc1c92fcf40","type":"BoxZoomTool"},{"id":"1707fb6f-6ac9-483a-9730-41af8058c312","type":"SaveTool"},{"id":"031b003e-62d7-4c77-8ece-6639852ac0b9","type":"ResetTool"},{"id":"100febae-ec5b-4d59-a563-e2a143e8f893","type":"HelpTool"}]},"id":"e7ee4c9b-2961-4719-a369-ff801a00b591","type":"Toolbar"},{"attributes":{"plot":null,"text":"simple line example"},"id":"60a320a3-c418-4945-93b5-68f00ab25bff","type":"Title"},{"attributes":{"plot":{"id":"980fa5fe-2358-4812-aee1-07958389ee94","subtype":"Figure","type":"Plot"}},"id":"1707fb6f-6ac9-483a-9730-41af8058c312","type":"SaveTool"},{"attributes":{},"id":"310abbe4-31f1-4f48-9059-b8a5f6d98b85","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"4617ec1b-9c7a-443e-a8f7-34bb5eecc0a9","type":"DataRange1d"},{"attributes":{"below":[{"id":"a6c11522-339c-40e1-8913-6eb195788cca","type":"LinearAxis"}],"left":[{"id":"d1979ad9-2e45-478c-84f4-1d1b1eac866f","type":"LinearAxis"}],"renderers":[{"id":"a6c11522-339c-40e1-8913-6eb195788cca","type":"LinearAxis"},{"id":"56229b17-d838-4f74-919e-a58acb6bbc5a","type":"Grid"},{"id":"d1979ad9-2e45-478c-84f4-1d1b1eac866f","type":"LinearAxis"},{"id":"f10cf991-4633-421f-8e53-766f27a30887","type":"Grid"},{"id":"b95e11bc-b970-474b-9d9d-92fe3ca3996f","type":"BoxAnnotation"},{"id":"4b3f8ac3-9250-4b2e-9aa5-e56829e4ac94","type":"Legend"},{"id":"249437d2-6b ...
